# %%
import matplotlib.pyplot as plt
print(plt.__package__)#to see the package name
# Out:
# matplotlib

# %%
plt.figure(figsize = (6, 4))
plt.plot([1, 2, 3, 4, 5], [4, 5, 6, 7, 8])
plt.show()

# %% [markdown]
# # Simple Line plot

# %%
x = [1, 2, 3, 4]
y = [10, 20, 30, 40]

plt.plot(x, y, marker = 'o', linestyle = '-', color = 'b')

plt.xlabel("X - axix label")
plt.ylabel("Y - axix label")
plt.title("Simple Line plot")
plt.show()

# %% [markdown]
# # Scatter plot

# %%
x = [1, 2, 3, 4]
y = [10, 20, 30, 40]

plt.scatter(x, y, color = 'y', marker = '*')
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
plt.title("Scatter plot")
plt.show()

# %% [markdown]
# # Bar plott

# %%
categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 8]

plt.bar(categories, values, color = 'Black')
plt.xlabel("X - axis label")
plt.ylabel("Y - axis label")
plt.title("Bar plot")
plt.show()

# %% [markdown]
# #
# Histogram

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.randn(1000)
plt.hist(data, bins = 30, color = 'purple', edgecolor = 'black')

plt.xlabel("Bins")
plt.ylabel("Frequency")
plt.title("Histogram Example")
plt.show()

# %%
sizes = [20, 30, 40, 50]
plt.pie(sizes)
labels = ['JS', 'java', 'DSA', 'Angular']
colors = ['blue', 'red', 'orange', 'green']
plt.pie(sizes, labels = labels, colors = colors, autopct = '%1.1f%%',shadow = True) 
plt.show()

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in c:\users\k.nisarga\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

data = pd.DataFrame({
    "x":[1,2,3,4,5],
    "y":[10,20,15,40,50]
})

sns.lineplot(x="x",y="y",data=data)
plt.title("Seaborn line plot")
plt.show()
